# %%
import pandas as pd
import numpy as np

# %%
DMtable =pd.read_table('DirectMail.txt',sep ='\t')

# %%
DMtable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29904 entries, 0 to 29903
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   AGE      29904 non-null  int64
#  1   CRED     29871 non-null  float64
#  2   MS       29904 non-null  object
#  3   HEQ      29904 non-null  float64
#  4   INCOME   29904 non-null  int64
#  5   DEPC     29904 non-null  object
#  6   MOB      29904 non-null  object
#  7   MILEAGE  29904 non-null  float64
#  8   RESTYPE  29904 non-null  object
#  9   GENDER   29904 non-null  object
#  10  EMP_STA  29904 non-null  object
#  11  RES_STA  29904 non-null  object
#  12  DELINQ   29904 non-null  int64
#  13  NUMTR    29904 non-null  int64
#  14  MRTGI    29904 non-null  object
#  15  MFDU     29904 non-null  int64
#  16  resp     29904 non-null  int64
#  17  female   29904 non-null  int64
#  18  HOME     29904 non-null  int64
#  19  CONDO    29904 non-null  int64
# ...

# %%
DM = DMtable.drop(['emp1','emp2','female'],axis=1)

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29904 entries, 0 to 29903
# Data columns (total 23 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   AGE      29904 non-null  int64
#  1   CRED     29871 non-null  float64
#  2   MS       29904 non-null  object
#  3   HEQ      29904 non-null  float64
#  4   INCOME   29904 non-null  int64
#  5   DEPC     29904 non-null  object
#  6   MOB      29904 non-null  object
#  7   MILEAGE  29904 non-null  float64
#  8   RESTYPE  29904 non-null  object
#  9   GENDER   29904 non-null  object
#  10  EMP_STA  29904 non-null  object
#  11  RES_STA  29904 non-null  object
#  12  DELINQ   29904 non-null  int64
#  13  NUMTR    29904 non-null  int64
#  14  MRTGI    29904 non-null  object
#  15  MFDU     29904 non-null  int64
#  16  resp     29904 non-null  int64
#  17  HOME     29904 non-null  int64
#  18  CONDO    29904 non-null  int64
#  19  COOP     29904 non-null  int64
# ...

# %%
DM[(DM.CRED>720 )]
# Out:
#        AGE    CRED MS   HEQ  INCOME DEPC MOB  MILEAGE RESTYPE GENDER  ...  \
# 90      18   730.0  U   0.1      20    N   Y   14.265    HOME      M  ...
# 296     25   732.0  M   0.1      20    N   Y   11.588    HOME      F  ...
# 297     22   746.0  U   0.1      20    N   Y    4.936    HOME      M  ...
# 298     24   936.0  M  30.0      20    Y   N   18.438  RENTER      F  ...
# 299     24   966.0  M  50.0      40    N   N   19.118    HOME      M  ...
# ...    ...     ... ..   ...     ...  ...  ..      ...     ...    ...  ...
# 29899   56  1789.0  M  30.0      30    Y   Y   17.302    COOP      F  ...
# 29900   58  1789.0  U  30.0      40    Y   N   10.509    HOME      M  ...
# 29901   64  1789.0  M  30.0      40    Y   N    4.749  RENTER      F  ...
# 29902   64  1789.0  M  30.0      40    Y   Y   11.110    HOME      F  ...
# 29903   68  1789.0  M  90.0      40    N   Y   18.653    HOME      M  ...
#
#       NUMTR MRTGI  MFDU  resp HOME  CONDO  COOP  renter  msn  cuscode
# ...

# %%
DM = DM.drop(DM[(DM.CRED>720 )].index)

# %%
DM[(DM.CRED>720 )]
# Out:
# Empty DataFrame
# Columns: [AGE, CRED, MS, HEQ, INCOME, DEPC, MOB, MILEAGE, RESTYPE, GENDER, EMP_STA, RES_STA, DELINQ, NUMTR, MRTGI, MFDU, resp, HOME, CONDO, COOP, renter, msn, cuscode]
# Index: []
#
# [0 rows x 23 columns]

# %%
DM['test'] = np.select([(DM['GENDER']=='M') & (DM['MILEAGE'] > 30 ) & (DM['RESTYPE']== 'HOME') , (DM['GENDER']=='M') & (DM['RESTYPE'] == 'HOME') & (DM['MILEAGE'] <30) ], ['A','F'], default='R' )

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28270 entries, 0 to 29887
# Data columns (total 24 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   AGE      28270 non-null  int64
#  1   CRED     28237 non-null  float64
#  2   MS       28270 non-null  object
#  3   HEQ      28270 non-null  float64
#  4   INCOME   28270 non-null  int64
#  5   DEPC     28270 non-null  object
#  6   MOB      28270 non-null  object
#  7   MILEAGE  28270 non-null  float64
#  8   RESTYPE  28270 non-null  object
#  9   GENDER   28270 non-null  object
#  10  EMP_STA  28270 non-null  object
#  11  RES_STA  28270 non-null  object
#  12  DELINQ   28270 non-null  int64
#  13  NUMTR    28270 non-null  int64
#  14  MRTGI    28270 non-null  object
#  15  MFDU     28270 non-null  int64
#  16  resp     28270 non-null  int64
#  17  HOME     28270 non-null  int64
#  18  CONDO    28270 non-null  int64
#  19  COOP     28270 non-null  int64
# ...

# %%
DM['test']
# Out:
# 0        F
# 1        F
# 2        F
# 3        R
# 4        R
#         ..
# 29883    R
# 29884    F
# 29885    F
# 29886    F
# 29887    R
# Name: test, Length: 28270, dtype: object

# %%
DM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28270 entries, 0 to 29887
# Data columns (total 24 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   AGE      28270 non-null  int64
#  1   CRED     28237 non-null  float64
#  2   MS       28270 non-null  object
#  3   HEQ      28270 non-null  float64
#  4   INCOME   28270 non-null  int64
#  5   DEPC     28270 non-null  object
#  6   MOB      28270 non-null  object
#  7   MILEAGE  28270 non-null  float64
#  8   RESTYPE  28270 non-null  object
#  9   GENDER   28270 non-null  object
#  10  EMP_STA  28270 non-null  object
#  11  RES_STA  28270 non-null  object
#  12  DELINQ   28270 non-null  int64
#  13  NUMTR    28270 non-null  int64
#  14  MRTGI    28270 non-null  object
#  15  MFDU     28270 non-null  int64
#  16  resp     28270 non-null  int64
#  17  HOME     28270 non-null  int64
#  18  CONDO    28270 non-null  int64
#  19  COOP     28270 non-null  int64
# ...

# %%
DM = DM.drop([(DM['AGE'>62] & DM['CRED'>=750])].index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-6ca1bfb515a8> in <module>
# ----> 1 DM = DM.drop([(DM['AGE'>62] & DM['CRED'>=750])].index)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df2 =pd.read_csv('emails.csv',sep='\t')
df2
# Out:
#           mutual funds  \
# 0       mobile banking
# 1         mutual funds
# 2         mutual funds
# 3         mutual funds
# 4         mutual funds
# ...                ...
# 5479      mutual funds
# 5480         complaint
# 5481      mutual funds
# 5482         complaint
# 5483  internet banking
#
#      champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares reuter
# 0     computer terminal systems cpml completes sale ...
# 1     cobanco inc cbco year net shr cts vs dlrs net ...
# 2     am international inc am nd qtr jan oper shr lo...
# 3     brown forman inc bfd th qtr net shr one dlr vs...
# 4     dean foods df sees strong th qtr mutual fundsi...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5484 entries, 0 to 5483
# Data columns (total 2 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                     --------------  -----
# ...

# %%
df2.head()
# Out:
#      mutual funds  \
# 0  mobile banking
# 1    mutual funds
# 2    mutual funds
# 3    mutual funds
# 4    mutual funds
#
#   champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares reuter
# 0  computer terminal systems cpml completes sale ...
# 1  cobanco inc cbco year net shr cts vs dlrs net ...
# 2  am international inc am nd qtr jan oper shr lo...
# 3  brown forman inc bfd th qtr net shr one dlr vs...
# 4  dean foods df sees strong th qtr mutual fundsi...

# %%
df2.columns =['type','email']

# %%
df2.head()
# Out:
#              type                                              email
# 0  mobile banking  computer terminal systems cpml completes sale ...
# 1    mutual funds  cobanco inc cbco year net shr cts vs dlrs net ...
# 2    mutual funds  am international inc am nd qtr jan oper shr lo...
# 3    mutual funds  brown forman inc bfd th qtr net shr one dlr vs...
# 4    mutual funds  dean foods df sees strong th qtr mutual fundsi...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5484 entries, 0 to 5483
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   type    5484 non-null   object
#  1   email   5484 non-null   object
# dtypes: object(2)
# memory usage: 85.8+ KB

# %%
l=[]
for i in df2.iloc[0:,1]:
    l.append(len(i.split()))
l
# Out:
# [211,
#  44,
#  93,
#  35,
#  245,
#  201,
#  54,
#  55,
#  20,
#  56,
#  36,
#  84,
#  71,
#  372,
#  194,
#  69,
#  38,
#  17,
#  172,
#  177,
#  53,
#  32,
#  57,
#  57,
#  20,
#  91,
#  62,
#  44,
#  17,
#  16,
#  35,
#  18,
#  34,
#  65,
#  40,
#  19,
#  589,
#  80,
#  120,
#  67,
#  98,
#  40,
#  97,
#  43,
#  8,
#  147,
#  42,
#  100,
#  248,
#  46,
#  15,
#  47,
#  19,
#  19,
#  454,
#  179,
#  44,
#  79,
#  37,
#  20,
#  104,
#  151,
#  60,
#  41,
#  18,
#  44,
#  21,
#  16,
#  46,
#  43,
#  47,
#  29,
#  39,
#  30,
#  35,
#  13,
#  59,
#  72,
#  18,
#  87,
#  30,
#  54,
#  86,
#  95,
#  60,
#  119,
#  279,
#  113,
#  462,
#  439,
#  144,
#  314,
#  476,
#  352,
#  204,
#  146,
#  92,
#  379,
#  138,
#  118,
#  14,
#  54,
#  411,
#  183,
#  84,
#  185,
#  211,
#  330,
#  104,
#  86,
#  590,
#  93,
#  102,
#  112,
#  110,
#  259,
#  442,
#  100,
#  559,
#  145,
#  111,
#  109,
#  531,
#  37,
#  42,
#  59,
#  99,
#  10,
#  80,
#  47,
#  109,
#  262,
#  9,
#  246,
#  15,
# ...

# %%
df2['taille'] = pd.Series(l).values

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5484 entries, 0 to 5483
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   type    5484 non-null   object
#  1   email   5484 non-null   object
#  2   taille  5484 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 128.7+ KB

# %%
df2
# Out:
#                   type                                              email  \
# 0       mobile banking  computer terminal systems cpml completes sale ...
# 1         mutual funds  cobanco inc cbco year net shr cts vs dlrs net ...
# 2         mutual funds  am international inc am nd qtr jan oper shr lo...
# 3         mutual funds  brown forman inc bfd th qtr net shr one dlr vs...
# 4         mutual funds  dean foods df sees strong th qtr mutual fundsi...
# ...                ...                                                ...
# 5479      mutual funds  kelly oil and gas partners kly year dec shr ct...
# 5480         complaint  japan seeks to strengthen paris currency accor...
# 5481      mutual funds  tcw convertible securities cvt sets dividend t...
# 5482         complaint  south korean won fixed at month high the bank ...
# 5483  internet banking  australian unions launch new south wales strik...
#
#       taille
# 0        211
# 1         44
# 2         93
# 3         35
# ...

# %%
import string

def RMV(txt):
    txt_clean = [word for word in txt if word not in string.punctuation]
    return txt_clean

# %%
strt= RMV('ksjdf .fsdfucds. sdnconc.')
strt
# Out:
# ['k',
#  's',
#  'j',
#  'd',
#  'f',
#  ' ',
#  'f',
#  's',
#  'd',
#  'f',
#  'u',
#  'c',
#  'd',
#  's',
#  ' ',
#  's',
#  'd',
#  'n',
#  'c',
#  'o',
#  'n',
#  'c']

# %%
RMV(df2.email)
df2
# Out:
#                   type                                              email  \
# 0       mobile banking  computer terminal systems cpml completes sale ...
# 1         mutual funds  cobanco inc cbco year net shr cts vs dlrs net ...
# 2         mutual funds  am international inc am nd qtr jan oper shr lo...
# 3         mutual funds  brown forman inc bfd th qtr net shr one dlr vs...
# 4         mutual funds  dean foods df sees strong th qtr mutual fundsi...
# ...                ...                                                ...
# 5479      mutual funds  kelly oil and gas partners kly year dec shr ct...
# 5480         complaint  japan seeks to strengthen paris currency accor...
# 5481      mutual funds  tcw convertible securities cvt sets dividend t...
# 5482         complaint  south korean won fixed at month high the bank ...
# 5483  internet banking  australian unions launch new south wales strik...
#
#       taille
# 0        211
# 1         44
# 2         93
# 3         35
# ...

# %%
df3 = pd.concat([DM,df2],axis=1)

# %%
df3
# Out:
#         AGE   CRED MS   HEQ  INCOME DEPC MOB  MILEAGE RESTYPE GENDER  ...  \
# 0      20.0  543.0  U   0.1    20.0    N   Y   14.418    HOME      M  ...
# 1      18.0  445.0  U   0.1    20.0    N   Y    0.311    HOME      M  ...
# 2      19.0  423.0  U   0.1    20.0    N   N   17.876    HOME      M  ...
# 3      18.0  416.0  X   0.1    20.0    N   Y   17.084    HOME      F  ...
# 4      18.0  522.0  U   0.1    20.0    Y   Y   16.510    HOME      F  ...
# ...     ...    ... ..   ...     ...  ...  ..      ...     ...    ...  ...
# 29883  55.0    NaN  M  30.0    40.0    N   Y    7.842  RENTER      F  ...
# 29884  71.0    NaN  M  30.0    20.0    N   N   14.277    HOME      M  ...
# 29885  73.0    NaN  M  30.0    50.0    N   Y   15.627    HOME      M  ...
# 29886  68.0    NaN  M  90.0    40.0    N   Y   18.653    HOME      M  ...
# 29887  68.0    NaN  U  10.0    50.0    N   N   10.530  RENTER      F  ...
#
#       HOME CONDO  COOP  renter  msn  cuscode  test            type  \
# ...

# %%
df3.dropna() 
df3
# Out:
#         AGE   CRED MS   HEQ  INCOME DEPC MOB  MILEAGE RESTYPE GENDER  ...  \
# 0      20.0  543.0  U   0.1    20.0    N   Y   14.418    HOME      M  ...
# 1      18.0  445.0  U   0.1    20.0    N   Y    0.311    HOME      M  ...
# 2      19.0  423.0  U   0.1    20.0    N   N   17.876    HOME      M  ...
# 3      18.0  416.0  X   0.1    20.0    N   Y   17.084    HOME      F  ...
# 4      18.0  522.0  U   0.1    20.0    Y   Y   16.510    HOME      F  ...
# ...     ...    ... ..   ...     ...  ...  ..      ...     ...    ...  ...
# 29883  55.0    NaN  M  30.0    40.0    N   Y    7.842  RENTER      F  ...
# 29884  71.0    NaN  M  30.0    20.0    N   N   14.277    HOME      M  ...
# 29885  73.0    NaN  M  30.0    50.0    N   Y   15.627    HOME      M  ...
# 29886  68.0    NaN  M  90.0    40.0    N   Y   18.653    HOME      M  ...
# 29887  68.0    NaN  U  10.0    50.0    N   N   10.530  RENTER      F  ...
#
#       HOME CONDO  COOP  renter  msn  cuscode  test            type  \
# ...
